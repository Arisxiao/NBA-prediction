# %%
# %run Preprocessing_main.ipynb

# %%
data_22 = pd.read_excel('./2022pred/2022adv.xlsx', header = 0)

# %%
data_22
# Out:
#       Rk                       Player Pos  Age   Tm   G    MP   PER    TS%  \
# 0      1   Precious Achiuwa\achiupr01   C   22  TOR  73  1725  12.7  0.503
# 1      2       Steven Adams\adamsst01   C   28  MEM  76  1999  17.6  0.560
# 2      3        Bam Adebayo\adebaba01   C   24  MIA  56  1825  21.8  0.608
# 3      4       Santi Aldama\aldamsa01  PF   21  MEM  32   360  10.2  0.452
# 4      5  LaMarcus Aldridge\aldrila01   C   36  BRK  47  1050  19.6  0.604
# ..   ...                          ...  ..  ...  ...  ..   ...   ...    ...
# 807  808     Thaddeus Young\youngth01  PF   33  TOR  26   475  15.8  0.526
# 808  809         Trae Young\youngtr01  PG   23  ATL  76  2652  25.4  0.603
# 809  810     Omer Yurtseven\yurtsom01   C   23  MIA  56   706  17.4  0.546
# 810  811        Cody Zeller\zelleco01   C   29  POR  27   355  17.2  0.627
# 811  812        Ivica Zubac\zubaciv01   C   24  LAC  76  1852  19.2  0.660
#
# ...

# %%
all_adv.head()
# Out:
#                  Player Pos  Age   Tm   G    MP   PER    TS%   3PAr    FTr  \
# 3   Shareef Abdur-Rahim  SF   23  VAN  82  3223  20.2  0.547  0.075  0.431
# 5             Ray Allen  SG   24  MIL  82  3070  20.6  0.570  0.288  0.282
# 8        Derek Anderson  SG   25  LAC  64  2201  16.9  0.542  0.207  0.359
# 9        Kenny Anderson  PG   29  BOS  82  2593  17.4  0.524  0.223  0.257
# 10        Nick Anderson  SG   32  SAC  72  2094  11.8  0.479  0.508  0.097
#
#     ...  USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP       year
# 3   ...  25.0  6.2  2.6   8.8  0.132   1.8   0.5  2.3   3.5  1999-2000
# 5   ...  25.6  9.0  1.0  10.1  0.157   5.0  -2.0  3.0   3.9  1999-2000
# 8   ...  23.4  3.1  0.3   3.3  0.073   1.7  -1.9 -0.2   1.0  1999-2000
# 9   ...  20.5  5.4  1.9   7.3  0.136   2.6  -1.4  1.2   2.1  1999-2000
# 10  ...  18.1  0.3  2.5   2.8  0.064  -0.1   0.4  0.3   1.2  1999-2000
#
# [5 rows x 27 columns]
